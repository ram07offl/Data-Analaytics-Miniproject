# %%
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as n

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as p

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
a=p.read_csv("C:\\Users\\aedpu\\OneDrive\\Documents\\MINIPROJECT\\bodyfat.csv")

# %%
a
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# ...

# %%
a.shape
# Out:
# (252, 15)

# %%
a.info
# Out:
# <bound method DataFrame.info of      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# ...

# %%
p=a.drop(["Density","Age","Weight","Height","Neck","Chest","Abdomen","Hip","Thigh","Knee","Ankle","Biceps","Forearm"],axis=1)

# %%
p
# Out:
#      BodyFat  Wrist
# 0       12.3   17.1
# 1        6.1   18.2
# 2       25.3   16.6
# 3       10.4   18.2
# 4       28.7   17.7
# ..       ...    ...
# 247     11.0   18.5
# 248     33.6   20.1
# 249     29.3   18.0
# 250     26.0   19.8
# 251     31.9   20.9
#
# [252 rows x 2 columns]

# %%
x=p.iloc[:,0].values.reshape(-1,1)
y=p.iloc[:,1].values.reshape(-1,1)

# %%
x
# Out:
# array([[12.3],
#        [ 6.1],
#        [25.3],
#        [10.4],
#        [28.7],
#        [20.9],
#        [19.2],
#        [12.4],
#        [ 4.1],
#        [11.7],
#        [ 7.1],
#        [ 7.8],
#        [20.8],
#        [21.2],
#        [22.1],
#        [20.9],
#        [29. ],
#        [22.9],
#        [16. ],
#        [16.5],
#        [19.1],
#        [15.2],
#        [15.6],
#        [17.7],
#        [14. ],
#        [ 3.7],
#        [ 7.9],
#        [22.9],
#        [ 3.7],
#        [ 8.8],
#        [11.9],
#        [ 5.7],
#        [11.8],
#        [21.3],
#        [32.3],
#        [40.1],
#        [24.2],
#        [28.4],
#        [35.2],
#        [32.6],
#        [34.5],
#        [32.9],
#        [31.6],
#        [32. ],
#        [ 7.7],
#        [13.9],
#        [10.8],
#        [ 5.6],
#        [13.6],
#        [ 4. ],
#        [10.2],
#        [ 6.6],
#        [ 8. ],
#        [ 6.3],
#        [ 3.9],
#        [22.6],
#        [20.4],
#        [28. ],
# ...

# %%
y
# Out:
# array([[17.1],
#        [18.2],
#        [16.6],
#        [18.2],
#        [17.7],
#        [18.8],
#        [17.7],
#        [18.8],
#        [18.2],
#        [19.2],
#        [18.5],
#        [19. ],
#        [17.7],
#        [18.8],
#        [18.2],
#        [16.9],
#        [17.3],
#        [19.3],
#        [18.5],
#        [18.2],
#        [18.4],
#        [19.9],
#        [16.7],
#        [17.1],
#        [17.6],
#        [17.7],
#        [16.5],
#        [17. ],
#        [17.2],
#        [17.6],
#        [18.4],
#        [17.9],
#        [18.8],
#        [18.7],
#        [19.7],
#        [17. ],
#        [19. ],
#        [19.4],
#        [21.4],
#        [18.3],
#        [21.4],
#        [17.4],
#        [18.4],
#        [18.8],
#        [16.1],
#        [18.3],
#        [17.3],
#        [17.9],
#        [16.3],
#        [16.8],
#        [17.3],
#        [17.2],
#        [16.9],
#        [18.5],
#        [18.5],
#        [18.9],
#        [18.5],
#        [19.2],
# ...

# %%
pip install -U scikit-learn
# Out:
# ...
#
# ...
#   Using cached scikit_learn-1.2.2-cp39-cp39-win_amd64.whl (8.4 MB)
# ...
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# ...
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
plt.scatter(x,y)
plt.xlabel("BodyFat")
plt.ylabel("Wrist")
plt.title('linear reg')
plt.show()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=0)

# %%
x_train.shape
# Out:
# (176, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
l=LinearRegression()

# %%
x_train
# Out:
# array([[18.3],
#        [ 7.5],
#        [28.7],
#        [20.1],
#        [29.8],
#        [13.8],
#        [ 8. ],
#        [21.5],
#        [ 7.9],
#        [16.1],
#        [21. ],
#        [10.9],
#        [34.5],
#        [21.2],
#        [10.4],
#        [19.3],
#        [14. ],
#        [11.9],
#        [12.5],
#        [26.1],
#        [20.4],
#        [20.4],
#        [14.7],
#        [16.5],
#        [24.4],
#        [21.8],
#        [ 3.9],
#        [28.7],
#        [31.4],
#        [ 6.6],
#        [25.3],
#        [26.7],
#        [25.4],
#        [24.4],
#        [14.9],
#        [ 7.1],
#        [10.3],
#        [26.6],
#        [18.6],
#        [32.9],
#        [22.1],
#        [22.9],
#        [10.2],
#        [14.9],
#        [19.1],
#        [16.9],
#        [10.8],
#        [16.9],
#        [11. ],
#        [16. ],
#        [ 7.1],
#        [18.7],
#        [30.7],
#        [12.4],
#        [21.8],
#        [18.1],
#        [17.3],
#        [29.4],
# ...

# %%
y_train
# Out:
# array([[19.1],
#        [18.6],
#        [17.7],
#        [18.1],
#        [18.3],
#        [18. ],
#        [16.9],
#        [17.4],
#        [16.5],
#        [19. ],
#        [19.4],
#        [19.2],
#        [21.4],
#        [18.8],
#        [18.2],
#        [18.1],
#        [17.6],
#        [18.4],
#        [15.8],
#        [20.2],
#        [18.5],
#        [18.7],
#        [17.6],
#        [18.2],
#        [18.5],
#        [17.1],
#        [18.5],
#        [18.7],
#        [19. ],
#        [17.2],
#        [16.6],
#        [17.6],
#        [17.7],
#        [18.1],
#        [18.8],
#        [18.5],
#        [18.3],
#        [19. ],
#        [18.3],
#        [17.4],
#        [18.2],
#        [17. ],
#        [17.3],
#        [18.8],
#        [18.4],
#        [19.9],
#        [17.3],
#        [17.8],
#        [18.5],
#        [17.6],
#        [17.4],
#        [19. ],
#        [19.1],
#        [18.9],
#        [17.7],
#        [17.6],
#        [17.7],
#        [17.7],
# ...

# %%
l.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=l.predict(x_test)

# %%
y_predict
# Out:
# array([[18.00779846],
#        [18.5305638 ],
#        [17.66529702],
#        [18.29261544],
#        [17.89603483],
#        [18.40798434],
#        [18.48730046],
#        [18.46566879],
#        [18.48730046],
#        [18.53416908],
#        [18.46566879],
#        [18.11235152],
#        [18.32866822],
#        [18.29622071],
#        [18.15200958],
#        [18.04385124],
#        [18.15561486],
#        [17.58237562],
#        [17.9176665 ],
#        [17.96453512],
#        [18.29261544],
#        [18.05827235],
#        [18.63511687],
#        [18.364721  ],
#        [18.26737849],
#        [18.70722243],
#        [17.70495508],
#        [18.37193156],
#        [18.35029989],
#        [18.58103769],
#        [18.6459327 ],
#        [18.53777435],
#        [18.56661658],
#        [17.97174567],
#        [18.79374911],
#        [18.06908819],
#        [18.40798434],
#        [18.31064183],
#        [18.11956208],
#        [17.96814039],
#        [18.18806237],
# ...

# %%
COMP=p.DataFrame(x_test,columns=['BodyFat'])

# %%
COMP
# Out:
#     BodyFat
# 0      12.5
# 1      27.0
# 2       3.0
# 3      20.4
# 4       9.4
# ..      ...
# 71     19.5
# 72      8.5
# 73     29.0
# 74      9.6
# 75     18.5
#
# [76 rows x 1 columns]

# %%
COMP['Wrist']=y_test

# %%
COMP
# Out:
#     BodyFat  Wrist
# 0      12.5   16.9
# 1      27.0   19.2
# 2       3.0   17.7
# 3      20.4   17.0
# 4       9.4   17.8
# ..      ...    ...
# 71     19.5   18.6
# 72      8.5   18.4
# 73     29.0   17.3
# 74      9.6   18.5
# 75     18.5   18.3
#
# [76 rows x 2 columns]

# %%
plt.scatter(x,y,color='orange')
plt.plot(x_test,y_predict,color='blue')
plt.xlabel('BodyFat')
plt.ylabel('CHA')
plt.title('linear reg')
plt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 0.6933238556830528

# %%
mean_absolute_error(y_test,y_predict)
# Out:
# 0.6801001690807059
